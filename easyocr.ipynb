# %%
import os
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
IMAGE_PATH = '/home/khundmeer/Documents/image_1.jpeg'

# %%
##Extracting text from the image English text 
reader = easyocr.Reader(['en'])
result = reader.readtext(IMAGE_PATH,paragraph="False")
result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [[[[33, 44], [298, 44], [298, 121], [33, 121]],
#   'UNDER CONSTRUCTION COMING SOON']]

# %%
##Drawing results for single-line text
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX

# %%
img = cv2.imread(IMAGE_PATH)
img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),2)
img = cv2.putText(img,text,top_left, font, 0.5,(255,0,0),1,cv2.LINE_AA)
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()
